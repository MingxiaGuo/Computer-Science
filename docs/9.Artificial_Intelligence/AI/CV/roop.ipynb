# %% [markdown]
# <a href="https://colab.research.google.com/github/MingxiaGuo/Artifical_Intelligence/blob/main/roop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Roop
#
# [Code](https://github.com/s0md3v/roop) | [Roop视频教程](https://www.youtube.com/watch?v=Vv940PZP_ew) | [Deepfacelab视频换脸教程](https://www.youtube.com/watch?v=YQHcp1-xhIk) | [Deepfacelive实时直播换脸教程](https://www.youtube.com/watch?v=mP_Jf_-ASE4)

# %% [markdown]
# ## 1. Clone and Installation

# %%
#克隆源码、下载安装依赖包
# !git clone https://github.com/s0md3v/roop
# %cd roop
# !pip install -r requirements.txt
#注意：卸载onnxruntime-gpu时程序会暂停运行，需要手动输入Y 回车确认，
# !pip uninstall onnxruntime onnxruntime-gpu
# !pip install onnxruntime-gpu

# %%
# !python --version
# Python 3.10.12
# Out:
# Python 3.10.12

# %% [markdown]
# ## 2. Inference

# %% [markdown]
# ![to.jpg](data:image/jpeg;base64,...)
#
# 下面步骤是执行视频换脸
#
# 先把图片和待换脸视频上传到左侧roop目录下，1.png是人脸图片 ，2.mp4是待换脸视频
#
# 转换完成后可在左侧选择将output.mp4视频下载下来

# %%
# !python run.py -s 1.png -t 2.mp4 -o output.mp4 --keep-frames --keep-fps --execution-provider cuda
