# %% [markdown]
# <a href="https://colab.research.google.com/github/MingxiaGuo/Artifical_Intelligence/blob/main/MODA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MODA: Mapping-Once Audio-driven Portrait Animation with Dual Attentions (ICCV-2023)
#
# [Code](https://github.com/DreamtaleCore/MODA) | [Project](https://liuyunfei.net/projects/iccv23-moda/) | [Paper](https://arxiv.org/abs/2307.10008)
#
# Yunfei Liu1, Lijian Lin1, Fei Yu2, Changyin Zhou2, Yu Li1
#
# 1International Digital Economy Academy (IDEA), Shenzhen, China,   2Vistring Inc., Hangzhou, China

# %% [markdown]
# ## 1. Installation

# %%
# 1. Installation
# !nvidia-smi
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py39_23.5.2-0-Linux-x86_64.sh
# !bash ./Miniconda3-py39_23.5.2-0-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages/')
# !conda create --name moda python=3.9 -y
# !git clone https://github.com/DreamtaleCore/MODA.git
# %cd MODA
# !bash ./install.sh
# Out:
# ...
#
# ...
#
# Installing conda env...
# done
# \

# %%
# Build 3DDFA-V2
# %cd data_prepare/3DDFA-V2
# !bash build.sh
cd ..
# Prepare face-parsing
# !git clone https://github.com/zllrunning/face-parsing.PyTorch face-parsing
# !pip install gdown
# %mkdir -p face-parsing/res/cp
# %cd face-parsing/res/cp
# !gdown https://drive.google.com/open?id=154JgKpzCPW82qINcVieuPH3fZ2e0P812
# %cd ../../../..

# %%
python process.py -i inputs/video/dir -o outputs/dir

# %%
#@title 2. Run
# !python inference.py -i


  # --audio_fp_or_dir AUDIO_FP_OR_DIR
  # --person_config PERSON_CONFIG
  # --output_dir OUTPUT_DIR
  # --n_sample N_SAMPLE
